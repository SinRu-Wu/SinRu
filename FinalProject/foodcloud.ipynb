# %%
import  matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
import PIL.Image as image

linux_font = r'..\wqy-microhei.ttc'
test ={u'牛油厚多士':0.2329,u'腸仔煎蛋白':0.1164,u'鮑魚火腿絲湯通粉':0.1164,u'公仔麵':0.4899,u'皮蛋瘦肉粥油條':0.0582,u'煎腸粉':0.1164,
       u'鮮魚片粥煎腸粉':0.0582,u'豉汁蒸鳳爪':0.0534,u'鮑汁鳳爪':0.2387,u'黃沙豬潤腸':0.0922,u'鮮蝦燒賣皇':0.0922,u'五柳鮮蝦炸雲吞':0.0534,
       u'鳳凰捲':0.1408,u'豬扒包':0.2704,u'金沙蝦球':0.0397,u'檸檬王':0.1418,u'豬頸肉芝士汁撈公仔麵':0.0438,u'粥':0.6606,u'豆腐花':0.261,
       u'皮蛋酥':0.1381,u'老婆餅':0.1381,u'蛋黃蓮蓉酥':0.1381,u'魚蛋':0.2332,u'奶皇流沙包':0.1265,u'絲襪奶茶':0.2657,
       u'鏞記酒家':0.1452,u'煎蠔餅':0.1291,u'芝麻糊':0.4024,u'雙皮燉奶':0.1994,u'奶油豬仔包':0.1009,u'車仔麵':0.6424,u'雜碎麵':0.2938,
       u'哪喳麵':0.0367,u'燉雞蛋':0.0558,u'薑蔥鵝腸撈麵':0.0695,u'蝴蝶酥':0.1781,u'楊枝甘露':0.2385,u'魚四寶米線':0.0638,
       u'曲奇四重奏':0.2049,u'鴛鴦腸':0.0438,u'鴛鴦奶茶':0.2721,u'叉燒':0.1212,u'燒鵝':0.51,u'合益泰小食':0.0879,u'美利樓':0.3589,
       u'蘭芳園':0.4994,u'沾記雲吞麵':0.0331,u'九記牛腩':0.4925,u'雙拼叉燒':0.0343,u'燒乳豬':0.0343,u'燒臘':0.2223,u'燒賣':0.4811,
       u'酥皮焗叉燒包':0.1844,u'泰昌餅家':0.8721,u'蘿蔔糕':0.123,u'西多士':0.1893 }
plt.figure(figsize=(12, 10))
#tt = np.array(image.open('11.png'))
wc =WordCloud(font_path=linux_font, background_color ="white" ,height=900, width=900).fit_words(test)
plt.imshow(wc)
plt.axis("off")
plt.show()
