# %%
import  matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
import PIL.Image as image

linux_font = r'..\wqy-microhei.ttc'
test ={u'維多利亞港':15.351 ,u'迪士尼樂園':25.838 ,u'天星小輪':5.042 ,u'張保仔號':7.665 ,u'星巴克':5.001 ,u'太平山頂':19.286 
       ,u'女人街':4.783 ,u'凌霄閣':4.653 ,u'杜莎夫人蠟像館':11.037 ,u'星光大道':6.343 ,u'幻彩詠香江':3.936 ,u'天際100':6.731 
       ,u'海洋公園':9.129 ,u'蘭桂坊':3.662 ,u'廟街夜市':3.887 ,u'香港文化中心':0.506 ,u'香港會議展覽中心':1.008 ,u'赤柱':17.000 
       ,u'九廣鐵路鐘樓':4.473 ,u'昂坪360':11.901 ,u'石板街':10.893 ,u'金魚街':2.799 ,u'半山手扶梯':5.882 ,u'九龍公園':1.307 
       ,u'鴨打街':1.010 ,u'彩虹邨':7.129 ,u'元創方':1.182 ,u'波鞋街':2.304 ,u'東薈城':2.472 ,u'黃大仙祠':6.238 ,u'嘉咸街壁畫':6.589 
       ,u'大嶼山':8.652 ,u'九龍城寨':0.77,u'天壇大佛':8.658 ,u'都爹利街':2.322 ,u'時代廣場':4.455 ,u'荷李活道':4.183 ,u'擺花街':2.601
       ,u'聖約翰教堂':2.173 ,u'香港文武廟':0.718 ,u'香港中文大學':0.740 ,u'金魚街':2.728 ,u'香港歷史博物館':0.662 ,u'花園街':1.179 
       ,u'通菜街':0.563 ,u'拉環畢街':0.256 ,u'東海濱平台花園':0.823 ,u'長沙灣時裝街':0.823 ,u'皇后大道':2.983 ,u'怪獸大廈':2.533 
       ,u'高街鬼屋':0.157 ,u'沙田賭馬':2.089 ,u'伊利近街':0.546 ,u'鴨寮街':1.327 ,u'彌敦道':4.787 ,u'利源東街':0.546 
       ,u'士丹頓街':0.546 ,u'利源西街':0.546 ,u'藝穗薈':0.331 ,u'馬莎百貨':0.273 ,u'些利街':0.829 ,u'瑪麗亞廣場':0.359 
       ,u'科學館':0.995 ,u'志蓮淨苑':1.332 ,u'1881Heritage':0.614 ,u'大澳魚村':2.220 ,u'須彌山':0.795 ,u'龍脊行山':0.719
       ,u'崇光百貨':0.947 ,u'天后廟':0.334 ,u'香港理工大學':0.719 ,u'竹搭鷹架樓':0.359 ,u'犍陀羅山':0.398 ,u'柏麗購物大道':0.426 
       ,u'柯士甸道':0.273 ,u'南蓮園池':0.848 }
plt.figure(figsize=(20, 15))
#tt = np.array(image.open('11.png'))
wc =WordCloud(font_path=linux_font, background_color ="white" ,height=800, width=800).fit_words(test)
plt.imshow(wc)
plt.axis("off")
plt.show()
